# %%
# %run pinn_trainer_trial.py
# Out:
# ...
# RUNNING EXPERIMENT: CASE=single_inclusion, NOISE=0pct
# ...
#
# Using device: cpu
# Starting training for case: single_inclusion, noise: 0pct
# Training finished. Total time: 663.99s
# Saved final models, predictions, and loss history for single_inclusion (0pct)
# Loss curve plot saved to data/plot_loss_curves_single_inclusion_0pct_1758893966.png
# Plot description: Shows the evolution of total, PDE, data, and TV loss components during training.
#
# ...
# RUNNING EXPERIMENT: CASE=single_inclusion, NOISE=1pct
# ...
#
# Using device: cpu
# Starting training for case: single_inclusion, noise: 1pct
# Training finished. Total time: 673.66s
# Saved final models, predictions, and loss history for single_inclusion (1pct)
# Loss curve plot saved to data/plot_loss_curves_single_inclusion_1pct_1758894640.png
# Plot description: Shows the evolution of total, PDE, data, and TV loss components during training.
#
# ...
# RUNNING EXPERIMENT: CASE=single_inclusion, NOISE=5pct
# ...
#
# Using device: cpu
# ...
