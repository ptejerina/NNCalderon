# %%
# %run pinn_trainer_trial.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/Calderon_Problem/Project1/experiment_generation_output/control/codebase/pinn_trainer_trial.py:11
#       8 from torch.utils.data import Dataset, DataLoader
#      10 # Ensure the codebase modules are accessible
# ---> 11 from codebase.pinn_framework import FourierFeatureEncoder, ConductivityNetwork, PotentialNetwork, CalderonPINN, init_weights
#      12 from codebase.fdm_forward_solver import FDMForwardSolver
#      14 # Set plotting style
#
# ModuleNotFoundError: No module named 'codebase'
